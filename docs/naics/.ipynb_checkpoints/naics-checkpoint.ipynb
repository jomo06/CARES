# %%
# setup
suppressWarnings(library(tidyverse))

# %%
# load csv -- prepared separately
# LARGE FILE - give it a minute
adbs = read_csv(here::here("data","tidy_data","adbs_naics.csv"),
               col_types = "ccccciiccccciccccdcccccccl")
# note: providing col specifications in shorthand due to large amount of NAs

# %%
# glimpse
glimpse(adbs)
# Out:
# Rows: 4,885,388
# Columns: 26
# $ LoanRange            <chr> "a $5-10 million", "a $5-10 million", "a $5-10...
# $ BusinessName         <chr> "ARCTIC SLOPE NATIVE ASSOCIATION, LTD.", "CRUZ...
# $ Address              <chr> "7000 Uula St", "7000 East Palmer Wasilla Hwy"...
# $ City                 <chr> "BARROW", "PALMER", "ANCHORAGE", "ANCHORAGE", ...
# $ State                <chr> "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK"...
# $ Zip                  <int> 99723, 99645, 99503, 99515, 99645, 99503, 9950...
# $ NAICSCode            <int> 813920, 238190, 722310, 621111, 517311, 541330...
# $ BusinessType         <chr> "Non-Profit Organization", "Subchapter S Corpo...
# $ RaceEthnicity        <chr> "Unanswered", "Unanswered", "Unanswered", "Una...
# $ Gender               <chr> "Unanswered", "Unanswered", "Unanswered", "Una...
# $ Veteran              <chr> "Unanswered", "Unanswered", "Unanswered", "Una...
# $ NonProfit            <chr> "Y", NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N...
# $ JobsRetained         <int> 295, 215, 367, 0, 267, 231, 298, 439, 361, 0, ...
# $ DateApproved         <chr> "04/14/2020", "04/15/2020", "04/11/2020", "04/...
# $ Lender               <chr> "National Cooperative Bank, National Associati...
# $ CD                   <chr> "AK - 00", "AK - 00", "AK - 00", "AK - 00", "A...
# $ source_file          <chr> "data/All Data By State//150k plus/PPP Data 15...
# $ LoanAmount           <dbl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA...
# $ LoanRange_Unified    <chr> "a $5-10 million", "a $5-10 million", "a $5-10...
# $ JobsRetained_Grouped <chr> "c 200 - 300", "c 200 - 300", "b 300 - 400", "...
# $ naics_lvl_1          <chr> "Other Services (except Public Administration)...
# $ naics_lvl_2          <chr> "Religious, Grantmaking, Civic, Professional, ...
# $ naics_lvl_3          <chr> "Business, Professional, Labor, Political, and...
# $ naics_lvl_4          <chr> "Professional Organizations", "Other Foundatio...
# $ naics_lvl_5          <chr> "Professional Organizations", "Other Foundatio...
# $ naics_valid          <lgl> TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE...

# %%
# Examples of column specifications for NAICS:
adbs  %>% 
    select(starts_with("naics"))  %>% 
    sample_n(10)
# Out:
#    NAICSCode naics_lvl_1
# 1  813319    Other Services (except Public Administration)
# 2  722513    Accommodation and Food Services
# 3  488999    Transportation and Warehousing
# 4  621111    Health Care and Social Assistance
# 5  811121    Other Services (except Public Administration)
# 6  236220    Construction
# 7  541921    Professional, Scientific, and Technical Services
# 8  236115    Construction
# 9  721110    Accommodation and Food Services
# 10 722513    Accommodation and Food Services
#    naics_lvl_2
# 1  Religious, Grantmaking, Civic, Professional, and Similar Organizations
# 2  Food Services and Drinking Places
# 3  Support Activities for Transportation
# 4  Ambulatory Health Care Services
# 5  Repair and Maintenance
# 6  Construction of Buildings
# 7  Professional, Scientific, and Technical Services
# 8  Construction of Buildings
# 9  Accommodation
# 10 Food Services and Drinking Places
#    naics_lvl_3
# 1  Social Advocacy Organizations
# 2  Restaurants and Other Eating Places
# 3  Other Support Activities for Transportation
# 4  Offices of Physicians
# 5  Automotive Repair and Maintenance
# 6  Nonresidential Building Construction
# 7  Other Professional, Scientific, and Technical Services
# 8  Residential Building Construction
# 9  Traveler Accommodation
# 10 Restaurants and Other Eating Places
#    naics_lvl_4
# 1  Social Advocacy Organizations
# 2  Restaurants and Other Eating Places
# 3  Other Support Activities for Transportation
# 4  Offices of Physicians
# 5  Automotive Body, Paint, Interior, and Glass Repair
# 6  Commercial and Institutional Building Construction
# 7  Photographic Services
# 8  Residential Building Construction
# 9  Hotels (except Casino Hotels) and Motels
# 10 Restaurants and Other Eating Places
#    naics_lvl_5
# 1  Other Social Advocacy Organizations
# 2  Limited-Service Restaurants
# 3  All Other Support Activities for Transportation
# 4  Offices of Physicians (except Mental Health Specialists)
# 5  Automotive Body, Paint, and Interior Repair and Maintenance
# 6  Commercial and Institutional Building Construction
# 7  Photography Studios, Portrait
# 8  New Single-Family Housing Construction (except For-Sale Builders)
# 9  Hotels (except Casino Hotels) and Motels
# 10 Limited-Service Restaurants
#    naics_valid
# 1  TRUE
# 2  TRUE
# 3  TRUE
# 4  TRUE
# 5  TRUE
# 6  TRUE
# 7  TRUE
# 8  TRUE
# 9  TRUE
# 10 TRUE

# %%
# Look at all top-level NAICS industries in data
adbs %>% 
  count(naics_lvl_1) %>% 
  ggplot(aes(x = reorder(naics_lvl_1,n),
             y = n)) +
  geom_col() +
  coord_flip() +
  labs(x = "",
       y = "Count") +
  theme_minimal()
# Out:
# plot without title

# %%
# Use case example: filter to all healthcare-related PPP loans in Maryland
health_md = adbs  %>% 
    filter(State == "MD",
           naics_lvl_1 == "Health Care and Social Assistance"
          )

sample_n(health_md, 10) # sample 10
# Out:
#    LoanRange            BusinessName                   Address
# 1  NA                   NA                             NA
# 2  NA                   NA                             NA
# 3  NA                   NA                             NA
# 4  NA                   NA                             NA
# 5  NA                   NA                             NA
# 6  NA                   NA                             NA
# 7  NA                   NA                             NA
# 8  NA                   NA                             NA
# 9  NA                   NA                             NA
# 10 d $350,000-1 million WEST CECIL HEALTH CENTER, INC. 49 Rock Springs Rd
#    City               State Zip   NAICSCode BusinessType
# 1  WHEATON            MD    20902 621320    Subchapter S Corporation
# 2  GREENBELT          MD    20770 621210    Limited  Liability Company(LLC)
# 3  DUNKIRK            MD    20754 621310    Subchapter S Corporation
# 4  WESTMINSTER        MD    21157 621111    Limited  Liability Company(LLC)
# 5  FREDERICK          MD    21703 624190    Non-Profit Organization
# 6  CHEVY CHASE        MD    20815 621320    Partnership
# 7  MONTGOMERY VILLAGE MD    20886 621210    Corporation
# 8  GREENBELT          MD    20770 624410    Subchapter S Corporation
# 9  BOWIE              MD    20716 624190    Sole Proprietorship
# 10 CONOWINGO          MD    21918 621111    Non-Profit Organization
#    RaceEthnicity Gender     ...
# 1  Unanswered    Unanswered ...
# 2  Unanswered    Unanswered ...
# 3  Unanswered    Unanswered ...
# 4  Unanswered    Unanswered ...
# 5  Unanswered    Unanswered ...
# 6  Unanswered    Unanswered ...
# 7  Unanswered    Unanswered ...
# 8  Unanswered    Unanswered ...
# 9  Unanswered    Unanswered ...
# 10 Unanswered    Unanswered ...
#    source_file                                                   LoanAmount
# 1  data/All Data By State//Maryland/PPP Data up to 150k - MD.csv 17300.00
# 2  data/All Data By State//Maryland/PPP Data up to 150k - MD.csv 47500.00
# 3  data/All Data By State//Maryland/PPP Data up to 150k - MD.csv 89469.32
# 4  data/All Data By State//Maryland/PPP Data up to 150k - MD.csv 62175.00
# 5  data/All Data By State//Maryland/PPP Data up to 150k - MD.csv 49855.00
# 6  data/All Data By State//Maryland/PPP Data up to 150k - MD.csv 20400.00
# 7  data/All Data By State//Maryland/PPP Data up to 150k - MD.csv 51287.00
# 8  data/All Data By State//Maryland/PPP Data up to 150k - MD.csv 94728.00
# 9  data/All Data By State//Maryland/PPP Data up to 150k - MD.csv 19979.00
# 10 data/All Data By State//150k plus/PPP Data 150k plus.csv            NA
#    LoanRange_Unified     JobsRetained_Grouped naics_lvl_1
# 1  k   $1,000 -  $25,000 k      Zero          Health Care and Social Assistance
# 2  j  $25,000 -  $50,000 h   5 -  10          Health Care and Social Assistance
# 3  h  $75,000 - $100,000 h   5 -  10          Health Care and Social Assistance
# 4  i  $50,000 -  $75,000 i   2 -   5          Health Care and Social Assistance
# 5  j  $25,000 -  $50,000 h   5 -  10          Health Care and Social Assistance
# 6  k   $1,000 -  $25,000 j         1          Health Care and Social Assistance
# 7  i  $50,000 -  $75,000 h   5 -  10          Health Care and Social Assistance
# 8  h  $75,000 - $100,000 g  10 -  25          Health Care and Social Assistance
# 9  k   $1,000 -  $25,000 j         1          Health Care and Social Assistance
# 10 d $350,000-1 million  e  50 - 100          Health Care and Social Assistance
#    naics_lvl_2                     naics_lvl_3
# 1  Ambulatory Health Care Services Offices of Other Health Practitioners
# 2  Ambulatory Health Care Services Offices of Dentists
# 3  Ambulatory Health Care Services Offices of Other Health Practitioners
# 4  Ambulatory Health Care Services Offices of Physicians
# 5  Social Assistance               Individual and Family Services
# 6  Ambulatory Health Care Services Offices of Other Health Practitioners
# 7  Ambulatory Health Care Services Offices of Dentists
# 8  Social Assistance               Child Day Care Services
# 9  Social Assistance               Individual and Family Services
# 10 Ambulatory Health Care Services Offices of Physicians
#    naics_lvl_4
# 1  Offices of Optometrists
# 2  Offices of Dentists
# 3  Offices of Chiropractors
# 4  Offices of Physicians
# 5  Other Individual and Family Services
# 6  Offices of Optometrists
# 7  Offices of Dentists
# 8  Child Day Care Services
# 9  Other Individual and Family Services
# 10 Offices of Physicians
#    naics_lvl_5                                              naics_valid
# 1  Offices of Optometrists                                  TRUE
# 2  Offices of Dentists                                      TRUE
# 3  Offices of Chiropractors                                 TRUE
# 4  Offices of Physicians (except Mental Health Specialists) TRUE
# 5  Other Individual and Family Services                     TRUE
# 6  Offices of Optometrists                                  TRUE
# 7  Offices of Dentists                                      TRUE
# 8  Child Day Care Services                                  TRUE
# 9  Other Individual and Family Services                     TRUE
# 10 Offices of Physicians (except Mental Health Specialists) TRUE

# %%
# Further refine filters with additional NAICS levels: e.g., hospitals
health_md %>% 
    filter(naics_lvl_2 == "Hospitals")  %>% 
    sample_n(10) # sample 10
# Out:
#    LoanRange            BusinessName
# 1  d $350,000-1 million MIDATLANTIC UROLOGY ASSOCIATES LLC
# 2  NA                   NA
# 3  NA                   NA
# 4  NA                   NA
# 5  NA                   NA
# 6  NA                   NA
# 7  NA                   NA
# 8  NA                   NA
# 9  NA                   NA
# 10 NA                   NA
#    Address                 City          State Zip   NAICSCode
# 1  7500 GREENWAY CENTER DR GREENBELT     MD    20770 622110
# 2  NA                      ROCKVILLE     MD    20850 622310
# 3  NA                      WALDORF       MD    20601 622110
# 4  NA                      FT WASHINGTON MD    20744 622110
# 5  NA                      COLUMBIA      MD    21044 622110
# 6  NA                      GAITHERSBURG  MD    20877 622210
# 7  NA                      CATONSVILLE   MD    21228 622110
# 8  NA                      PARKVILLE     MD    21234 622110
# 9  NA                      LAUREL        MD    20707 622110
# 10 NA                      WESTMINSTER   MD    21157 622110
#    BusinessType                    RaceEthnicity Gender     ...
# 1  Corporation                     Unanswered    Unanswered ...
# 2  Self-Employed Individuals       Unanswered    Unanswered ...
# 3  Corporation                     Unanswered    Unanswered ...
# 4  Limited  Liability Company(LLC) Unanswered    Unanswered ...
# 5  Limited  Liability Company(LLC) Unanswered    Unanswered ...
# 6  Limited  Liability Company(LLC) Unanswered    Unanswered ...
# 7  Limited  Liability Company(LLC) Unanswered    Unanswered ...
# 8  Limited  Liability Company(LLC) Unanswered    Unanswered ...
# 9  Corporation                     Unanswered    Unanswered ...
# 10 Limited  Liability Company(LLC) Unanswered    Unanswered ...
#    source_file                                                   LoanAmount
# 1  data/All Data By State//150k plus/PPP Data 150k plus.csv          NA
# 2  data/All Data By State//Maryland/PPP Data up to 150k - MD.csv  20833
# 3  data/All Data By State//Maryland/PPP Data up to 150k - MD.csv 113500
# 4  data/All Data By State//Maryland/PPP Data up to 150k - MD.csv  16400
# 5  data/All Data By State//Maryland/PPP Data up to 150k - MD.csv  10697
# 6  data/All Data By State//Maryland/PPP Data up to 150k - MD.csv   8824
# 7  data/All Data By State//Maryland/PPP Data up to 150k - MD.csv  64852
# 8  data/All Data By State//Maryland/PPP Data up to 150k - MD.csv  21621
# 9  data/All Data By State//Maryland/PPP Data up to 150k - MD.csv  40000
# 10 data/All Data By State//Maryland/PPP Data up to 150k - MD.csv   5572
#    LoanRange_Unified     JobsRetained_Grouped naics_lvl_1
# 1  d $350,000-1 million  f  25 -  50          Health Care and Social Assistance
# 2  k   $1,000 -  $25,000 j         1          Health Care and Social Assistance
# 3  g $100,000 - $125,000 h   5 -  10          Health Care and Social Assistance
# 4  k   $1,000 -  $25,000 k      Zero          Health Care and Social Assistance
# 5  k   $1,000 -  $25,000 j         1          Health Care and Social Assistance
# 6  k   $1,000 -  $25,000 j         1          Health Care and Social Assistance
# 7  i  $50,000 -  $75,000 h   5 -  10          Health Care and Social Assistance
# 8  k   $1,000 -  $25,000 i   2 -   5          Health Care and Social Assistance
# 9  j  $25,000 -  $50,000 h   5 -  10          Health Care and Social Assistance
# 10 k   $1,000 -  $25,000 j         1          Health Care and Social Assistance
#    naics_lvl_2 naics_lvl_3
# 1  Hospitals   General Medical and Surgical Hospitals
# 2  Hospitals   Specialty (except Psychiatric and Substance Abuse) Hospitals
# 3  Hospitals   General Medical and Surgical Hospitals
# 4  Hospitals   General Medical and Surgical Hospitals
# 5  Hospitals   General Medical and Surgical Hospitals
# 6  Hospitals   Psychiatric and Substance Abuse Hospitals
# 7  Hospitals   General Medical and Surgical Hospitals
# 8  Hospitals   General Medical and Surgical Hospitals
# 9  Hospitals   General Medical and Surgical Hospitals
# 10 Hospitals   General Medical and Surgical Hospitals
#    naics_lvl_4
# 1  General Medical and Surgical Hospitals
# 2  Specialty (except Psychiatric and Substance Abuse) Hospitals
# 3  General Medical and Surgical Hospitals
# 4  General Medical and Surgical Hospitals
# 5  General Medical and Surgical Hospitals
# 6  Psychiatric and Substance Abuse Hospitals
# 7  General Medical and Surgical Hospitals
# 8  General Medical and Surgical Hospitals
# 9  General Medical and Surgical Hospitals
# 10 General Medical and Surgical Hospitals
#    naics_lvl_5                                                  naics_valid
# 1  General Medical and Surgical Hospitals                       TRUE
# 2  Specialty (except Psychiatric and Substance Abuse) Hospitals TRUE
# 3  General Medical and Surgical Hospitals                       TRUE
# 4  General Medical and Surgical Hospitals                       TRUE
# 5  General Medical and Surgical Hospitals                       TRUE
# 6  Psychiatric and Substance Abuse Hospitals                    TRUE
# 7  General Medical and Surgical Hospitals                       TRUE
# 8  General Medical and Surgical Hospitals                       TRUE
# 9  General Medical and Surgical Hospitals                       TRUE
# 10 General Medical and Surgical Hospitals                       TRUE
